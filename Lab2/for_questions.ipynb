# %%
import torch
import segmentation_models_pytorch as smp

# %% [markdown]
# # Зачем кратность 32? (подать картинку 257 x 257)

# %%
model = smp.Unet(
    encoder_name = 'resnet50', encoder_weights = 'imagenet', classes = 1, activation = 'sigmoid')

image = torch.randint(0, 255, (3, 257, 257))

# %%
output = model(image)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\Users\Sanya\Desktop\ИИ\Lab2\for_questions.ipynb Cell 4 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Sanya/Desktop/%D0%98%D0%98/Lab2/for_questions.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> output = model(image)
#
# File c:\Users\Sanya\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
# ...

# %% [markdown]
# # Что такое переобучение - рассказать на графиках лоссов

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
